# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
df_sat = pd.read_csv("../data/sat_2017.csv")
df_act = pd.read_csv("../data/act_2017.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
print(df_sat.info())
df_sat.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# ...

# %%
print(df_act.info())
df_act.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB
# None
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# - the Dataframe for the SAT
#     - 5 Columns are State, Participation, Evidence-Based Reading and Writing,	Math, and Total
#     - There are total of 51 entries in their DF, representing each of the 50 states and the DC
#     - Participation can be a float or an integer but is read as an object.
#         - Participation varies across the board and there are states with a 100% participation
#
# - The Dataframe for the ACT
#     - 7 Columns are broken down by State, Participation, English, Math, Reading, Science, and Composite
#     - National is the one additional row not present in the SAT row, therefore there are a total of 52 entries
#         - 50 states
#         - 1 DC
#         - 1 National
#     - Participation can be a float or an itnger but read as an object
#         - Participation varies across the board and there are states with a 100% participation as well

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
df_sat.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
df_act.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Answer:
#
# The data in both SAT and ACT are complete. There are no null, missing, or NaN values

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# - Since each test has varying degrees of participation it would be tough to directly compare all states together since it would only be resonable to compare values of participating levels.
# - The dataset represents an average score per state.  The sample sie of the students who took the exam as well as an observable STD of the sample sets aren't know.
#
# SAT:
# The minimum score is 400 and maxmimum of 1600 for the SAT, and 200-800 for each subset of test.
#
# ACT:
# The minimum is 1 and maximum score is 36 for each subset of test. All four test produces a composite score

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
df_sat.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# Participation is read as an object because of the % sign attached to the data, when it should be read as a integer or a float like the other computational data.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
df_sat["Participation"] = df_sat["Participation"].str.rstrip("%").astype("int64")
df_act["Participation"] = df_act["Participation"].str.rstrip("%").astype("int64")
#df['RAD'] = df['RAD'].map(lambda rc: np.nan if rc == '?' else float(rc))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
df_act["Composite"] = df_act["Composite"].str.rstrip("x").astype("float")

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
df_sat.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_act.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print(df_sat.dtypes)
print(df_act.dtypes)
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
new_sat_column_name = {
    "State":"state",
    "Participation":"sat_percent_participation_2017",
    "Evidence-Based Reading and Writing":"sat_reading_writing_2017",
    "Math":"sat_math_2017",
    "Total":"sat_composite_score_2017"
}

new_act_column_name = {
    "State":"state",
    "Participation":"act_percent_participation_2017",
    "English":"act_english_2017",
    "Math":"act_math_2017",
    "Reading": "act_reading_2017",
    "Science":"act_science_2107",
    "Composite":"act_composite_score_2017"
}

df_sat.rename(columns=new_sat_column_name, inplace=True)
df_act.rename(columns=new_act_column_name, inplace=True)

# %%
df_act.head()
# Out:
#       state  act_percent_participation_2017  act_english_2017  act_math_2017  \
# 0  National                              60              20.3           20.7
# 1   Alabama                             100              18.9           18.4
# 2    Alaska                              65              18.7           19.8
# 3   Arizona                              62              18.6           19.8
# 4  Arkansas                             100              18.9           19.0
#
#    act_reading_2017  act_science_2107  act_composite_score_2017
# 0              21.4              21.0                      21.0
# 1              19.7              19.4                      19.2
# 2              20.4              19.9                      19.8
# 3              20.1              19.8                      19.7
# 4              19.7              19.5                      19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|2017 SAT/ACT scores|states in the USA that are participating in a given college preparation test |
# |sat_percent_partcipation|integer|2017 SAT scores|The percent of college bound students in the state that participated in the SATs in 2017|
# |sat_reading_writing|float|2017 SAT scores|The average score for the SAT Evidence-Based Reading and Writing based on the students who partcipated in the SAT in 2017|
# |sat_math|float|2017 SAT scores|The average score for the SAT Math section based on the students who partcipated in the SAT in 2017|
# |sat_composite_score|float|2017 SAT scores|The average composite score for both the Math and Reading and Writing section, based on the students who partcipated in the SAT in 2017|
# |act_percent_partcipation|integer|2017 ACT scores|The percent of college bound students in the state that participated in the ACTs in 2017|
# |act_english|float|2017 SAT scores|The average score for the ACT English portion of the exam based on the students who partcipated in the ACT in 2017|
# |act_writing|float|2017 SAT scores|The average score for the ACT Writing portion of the exam based on the students who partcipated in the ACT in 2017|
# |act_math|float|2017 SAT scores|The average score for the ACT Math portion of the exam based on the students who partcipated in the ACT in 2017|
# |act_science|float|2017 SAT scores|The average score for the ACT Science portion of the exam based on the students who partcipated in the ACT in 2017|
# |act_composite_score|float|2017 SAT scores|The average composite score for the ACT exam based on the English, Math, Writing, Science portions of the exam.  The score is based on the students who partcipated in the ACT in 2017|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
df_act.drop([0], inplace=True)

# %%
df_act.head()
# Out:
#         state  act_percent_participation_2017  act_english_2017  \
# 1     Alabama                             100              18.9
# 2      Alaska                              65              18.7
# 3     Arizona                              62              18.6
# 4    Arkansas                             100              18.9
# 5  California                              31              22.5
#
#    act_math_2017  act_reading_2017  act_science_2107  act_composite_score_2017
# 1           18.4              19.7              19.4                      19.2
# 2           19.8              20.4              19.9                      19.8
# 3           19.8              20.1              19.8                      19.7
# 4           19.0              19.7              19.5                      19.4
# 5           22.7              23.1              22.2                      22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:

df_college_exam2017 = pd.merge(df_act, df_sat, on='state')

# %%
df_college_exam2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
# state                             51 non-null object
# act_percent_participation_2017    51 non-null int64
# act_english_2017                  51 non-null float64
# act_math_2017                     51 non-null float64
# act_reading_2017                  51 non-null float64
# act_science_2107                  51 non-null float64
# act_composite_score_2017          51 non-null float64
# sat_percent_participation_2017    51 non-null int64
# sat_reading_writing_2017          51 non-null int64
# sat_math_2017                     51 non-null int64
# sat_composite_score_2017          51 non-null int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
df_college_exam2017.to_csv(path_or_buf="../data/combined_2017.csv")

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#importing the csv file into panda as a dataframe to analyze
df_sat_2018 = pd.read_csv("../data/sat_2018b.csv")
df_act_2018 = pd.read_csv("../data/act_2018.csv")

# %%
#looking through the data to make sure that all dtypes are correct
df_sat_2018.head()
# Out:
#          State Participation  EBRW  Math  Total
# 0     Alabama             6%   595   571   1166
# 1      Alaska            43%   562   544   1106
# 2     Arizona            29%   577   572   1149
# 3    Arkansas             5%   592   576   1169
# 4  California            60%   540   536   1076

# %%
df_act_2018.head()
# Out:
#          state  act_percent_participation_2018  act_composite_score_2018
# 0     Alabama                              100                      19.1
# 1      Alaska                               33                      20.8
# 2     Arizona                               66                      19.2
# 3    Arkansas                              100                      19.4
# 4  California                               27                      22.7

# %%
#fixed most of the column issues when converting the data manually so now I will just put the files together 
#code
new_sat_column_name_2018 = {
    "State":"state",
    "Participation":"sat_percent_participation_2018",
    "EBRW":"sat_reading_writing_2018",
    "Math":"sat_math_2018",
    "Total":"sat_composite_score_2018"
}

new_act_column_name_2018 = {
    "state":"state",
    "act_percent_participation_2018":"act_percent_participation_2018",
    "act_composite_score_2018":"act_composite_score_2018"
}

df_sat_2018.rename(columns=new_sat_column_name_2018, inplace=True)
df_act_2018.rename(columns=new_act_column_name_2018, inplace=True)

# %%
df_sat_2018.head()
# Out:
#          state sat_percent_participation_2018  sat_reading_writing_2018  \
# 0     Alabama                              6%                       595
# 1      Alaska                             43%                       562
# 2     Arizona                             29%                       577
# 3    Arkansas                              5%                       592
# 4  California                             60%                       540
#
#    sat_math_2018  sat_composite_score_2018
# 0            571                      1166
# 1            544                      1106
# 2            572                      1149
# 3            576                      1169
# 4            536                      1076

# %%
#convert percent from object to a int 
df_sat_2018["sat_percent_participation_2018"] = df_sat_2018["sat_percent_participation_2018"].str.rstrip("%").astype("int64")

# %%
#merging the two df files on state column and renaming it as dataframe called df_college_exam2018
df_college_exam2018 = pd.merge(df_act_2018, df_sat_2018, on='state')

# %%
#exporting this file using relevant path
df_college_exam2018.to_csv(path_or_buf="../data/combined_2018.csv")

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
df_exam_2017 = pd.read_csv("../data/combined_2017.csv")
df_exam_2018 = pd.read_csv("../data/combined_2018.csv")

# %%
df_exam_2017.info()
df_exam_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 12 columns):
# Unnamed: 0                        51 non-null int64
# state                             51 non-null object
# act_percent_participation_2017    51 non-null int64
# act_english_2017                  51 non-null float64
# act_math_2017                     51 non-null float64
# act_reading_2017                  51 non-null float64
# act_science_2107                  51 non-null float64
# act_composite_score_2017          51 non-null float64
# sat_percent_participation_2017    51 non-null int64
# sat_reading_writing_2017          51 non-null int64
# sat_math_2017                     51 non-null int64
# sat_composite_score_2017          51 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 4.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
# Unnamed: 0                        51 non-null int64
# ...

# %%
#dropped the unnamed that showed up when i reuploaded the files
df_exam_2017.drop("Unnamed: 0", axis=1, inplace=True)
df_exam_2018.drop("Unnamed: 0", axis=1, inplace=True)

# %%
#Merge on unnamed 0 was easier because one of the states had conflict, because when i tried to do it by states my data kept disappearing
df_final = pd.merge(df_exam_2017, df_exam_2018, on="state")

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
df_final = pd.read_csv("../data/final.csv")
df_final.drop("Unnamed: 0", axis=1, inplace=True)
df_final.head(5)
# Out:
#         state  act_percent_participation_2017  act_english_2017  \
# 0     Alabama                             100              18.9
# 1      Alaska                              65              18.7
# 2     Arizona                              62              18.6
# 3    Arkansas                             100              18.9
# 4  California                              31              22.5
#
#    act_math_2017  act_reading_2017  act_science_2107  \
# 0           18.4              19.7              19.4
# 1           19.8              20.4              19.9
# 2           19.8              20.1              19.8
# 3           19.0              19.7              19.5
# 4           22.7              23.1              22.2
#
#    act_composite_score_2017  sat_percent_participation_2017  \
# 0                      19.2                               5
# 1                      19.8                              38
# 2                      19.7                              30
# ...

# %%
df_final.describe()
# Out:
#        act_percent_participation_2017  act_english_2017  act_math_2017  \
# count                       51.000000         51.000000      51.000000
# mean                        65.254902         20.931373      21.182353
# std                         32.140842          2.353677       1.981989
# min                          8.000000         16.300000      18.000000
# 25%                         31.000000         19.000000      19.400000
# 50%                         69.000000         20.700000      20.900000
# 75%                        100.000000         23.300000      23.100000
# max                        100.000000         25.500000      25.300000
#
#        act_reading_2017  act_science_2107  act_composite_score_2017  \
# count         51.000000         51.000000                 51.000000
# mean          22.013725         21.041176                 21.519608
# std            2.067271          3.182463                  2.020695
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def std_calc(x):
    sum_deviation = 0
    deviation = 0
    for value in x:
        deviation = (value - np.mean(x))**2
        sum_deviation = deviation + sum_deviation
    std_dev = ((sum_deviation)/len(x))**0.5
    return std_dev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
sd = df_final.iloc[:,1:].apply(std_calc)

# %%
np.std(df_final["act_percent_participation_2017"])
# Out:
# 31.824175751231806

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
#
# The np.std is closer to the the calculated value, but both were slighlty different form the describe way.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#info so I can see all the columns
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 17 columns):
# state                             51 non-null object
# act_percent_participation_2017    51 non-null int64
# act_english_2017                  51 non-null float64
# act_math_2017                     51 non-null float64
# act_reading_2017                  51 non-null float64
# act_science_2107                  51 non-null float64
# act_composite_score_2017          51 non-null float64
# sat_percent_participation_2017    51 non-null int64
# sat_reading_writing_2017          51 non-null int64
# sat_math_2017                     51 non-null int64
# sat_composite_score_2017          51 non-null int64
# act_percent_participation_2018    51 non-null int64
# act_composite_score_2018          51 non-null float64
# sat_percent_participation_2018    51 non-null int64
# sat_reading_writing_2018          51 non-null int64
# sat_math_2018                     51 non-null int64
# ...

# %%
#find the the year for the most participation
df_final.sort_values(by="act_percent_participation_2017", ascending=False).head(20)
# Out:
#              state  act_percent_participation_2017  act_english_2017  \
# 0          Alabama                             100              18.9
# 17        Kentucky                             100              19.6
# 49       Wisconsin                             100              19.7
# 44            Utah                             100              19.5
# 42       Tennessee                             100              19.5
# 40  South Carolina                             100              17.5
# 36        Oklahoma                             100              18.5
# 33  North Carolina                             100              17.8
# 28          Nevada                             100              16.3
# 26         Montana                             100              19.0
# 24     Mississippi                             100              18.2
# 23       Minnesota                             100              20.4
# 18       Louisiana                             100              19.4
# ...

# %%
df_final.sort_values(by="act_percent_participation_2017", ascending=False).tail(5)
# Out:
#             state  act_percent_participation_2017  act_english_2017  \
# 38   Pennsylvania                              23              23.4
# 39   Rhode Island                              21              24.0
# 7        Delaware                              18              24.1
# 29  New Hampshire                              18              25.4
# 19          Maine                               8              24.2
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 38           23.4              24.2              23.3
# 39           23.3              24.7              23.4
# 7            23.4              24.8              23.6
# 29           25.1              26.0              24.9
# 19           24.0              24.8              23.7
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 38                      23.7                              65
# 39                      24.0                              71
# ...

# %%
df_final.sort_values(by="sat_percent_participation_2017", ascending=False).head(5)
# Out:
#                    state  act_percent_participation_2017  act_english_2017  \
# 8   District of Columbia                              32              24.4
# 22              Michigan                              29              24.1
# 6            Connecticut                              31              25.5
# 7               Delaware                              18              24.1
# 29         New Hampshire                              18              25.4
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 8            23.5              24.9              23.5
# 22           23.7              24.5              23.8
# 6            24.6              25.6              24.6
# 7            23.4              24.8              23.6
# 29           25.1              26.0              24.9
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 8                       24.2                             100
# 22                      24.1                             100
# ...

# %%
df_final.sort_values(by="sat_percent_participation_2017", ascending=False).tail(5)
# Out:
#            state  act_percent_participation_2017  act_english_2017  \
# 3       Arkansas                             100              18.9
# 50       Wyoming                             100              19.4
# 34  North Dakota                              98              19.0
# 24   Mississippi                             100              18.2
# 15          Iowa                              67              21.2
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 3            19.0              19.7              19.5
# 50           19.8              20.8              20.6
# 34           20.4              20.5              20.6
# 24           18.1              18.8              18.8
# 15           21.3              22.6              22.1
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 3                       19.4                               3
# 50                      20.2                               3
# ...

# %%
df_final.sort_values(by="sat_percent_participation_2018", ascending=False).head(5)
# Out:
#           state  act_percent_participation_2017  act_english_2017  \
# 5      Colorado                             100              20.1
# 6   Connecticut                              31              25.5
# 7      Delaware                              18              24.1
# 22     Michigan                              29              24.1
# 12        Idaho                              38              21.9
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 5            20.3              21.2              20.9
# 6            24.6              25.6              24.6
# 7            23.4              24.8              23.6
# 22           23.7              24.5              23.8
# 12           21.8              23.0              22.1
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 5                       20.8                              11
# 6                       25.2                             100
# ...

# %%
df_final.sort_values(by="sat_percent_participation_2018", ascending=False).tail(5)
# Out:
#            state  act_percent_participation_2017  act_english_2017  \
# 24   Mississippi                             100              18.2
# 15          Iowa                              67              21.2
# 49     Wisconsin                             100              19.7
# 50       Wyoming                             100              19.4
# 34  North Dakota                              98              19.0
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 24           18.1              18.8              18.8
# 15           21.3              22.6              22.1
# 49           20.4              20.6              20.9
# 50           19.8              20.8              20.6
# 34           20.4              20.5              20.6
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 24                      18.6                               2
# 15                      21.9                               2
# ...

# %%
df_final.sort_values(by="act_percent_participation_2018", ascending=False).head(20)
# Out:
#              state  act_percent_participation_2017  act_english_2017  \
# 0          Alabama                             100              18.9
# 17        Kentucky                             100              19.6
# 49       Wisconsin                             100              19.7
# 44            Utah                             100              19.5
# 42       Tennessee                             100              19.5
# 40  South Carolina                             100              17.5
# 36        Oklahoma                             100              18.5
# 35            Ohio                              75              21.2
# 33  North Carolina                             100              17.8
# 28          Nevada                             100              16.3
# 27        Nebraska                              84              20.9
# 26         Montana                             100              19.0
# 24     Mississippi                             100              18.2
# ...

# %%
df_final.sort_values(by="act_percent_participation_2018", ascending=False).tail(5)
# Out:
#             state  act_percent_participation_2017  act_english_2017  \
# 38   Pennsylvania                              23              23.4
# 7        Delaware                              18              24.1
# 29  New Hampshire                              18              25.4
# 39   Rhode Island                              21              24.0
# 19          Maine                               8              24.2
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 38           23.4              24.2              23.3
# 7            23.4              24.8              23.6
# 29           25.1              26.0              24.9
# 39           23.3              24.7              23.4
# 19           24.0              24.8              23.7
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 38                      23.7                              65
# 7                       24.1                             100
# ...

# %% [markdown]
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT? -highest at 100% participation rate
# District of Columbia
# Connecticut
# Michigan
# Delaware
#
# lowest - at 2% Mississippi
# Iowa
# North Dakota
#
#     - 2018 SAT? at 100% participation rate
# Connecticut
# Michigan
# Delaware
# Idaho
# Colorado
#
# lowest - at 2% North Dakota
#     - 2017 ACT? at 100% the following states
# Alabama
# Arkansas
# Colorado
# Kentucky
# Louisiana
# Minnesota
# Mississippi
# Missouri
# Montana
# Nevada
# North Carolina
# Oklahoma
# South Carolina
# Tennessee
# Utah
# Wisconsin
# Wyoming
#
# Lowest at 8% Maine
#     - 2018 ACT? at 100 participation the following state
# Alabama
# Arkansas
# Kentucky
# Louisiana
# Mississippi
# Missouri
# Montana
# Nevada
# North Carolina
# Oklahoma
# South Carolina
# Tennessee
# Utah
# Wisconsin
# Wyoming
# Nebraska
# Ohio
#
# Lowest at 8% Maine

# %%
mean_act_score_2017= df_final.groupby("state")["act_composite_score_2017"].mean()
mean_act_score_2017.sort_values(ascending=False).head(5)
# Out:
# state
# New Hampshire           25.5
# Massachusetts           25.4
# Connecticut             25.2
# Maine                   24.3
# District of Columbia    24.2
# Name: act_composite_score_2017, dtype: float64

# %%
mean_act_score_2017.sort_values(ascending=False).tail(5)
# Out:
# state
# North Carolina    19.1
# Hawaii            19.0
# South Carolina    18.7
# Mississippi       18.6
# Nevada            17.8
# Name: act_composite_score_2017, dtype: float64

# %%
mean_act_score_2018= df_final.groupby("state")["act_composite_score_2018"].mean()
mean_act_score_2018.sort_values(ascending=False).head(5)
# Out:
# state
# Connecticut      25.6
# Massachusetts    25.5
# New Hampshire    25.1
# New York         24.5
# Michigan         24.4
# Name: act_composite_score_2018, dtype: float64

# %%
mean_act_score_2018.sort_values(ascending=False).tail(5)
# Out:
# state
# Alabama           19.1
# Hawaii            18.9
# Mississippi       18.6
# South Carolina    18.3
# Nevada            17.7
# Name: act_composite_score_2018, dtype: float64

# %%
mean_sat_score_2017= df_final.groupby("state")["sat_composite_score_2017"].mean()
mean_sat_score_2017.sort_values(ascending=False).head(5)
# Out:
# state
# Minnesota    1295
# Wisconsin    1291
# Iowa         1275
# Missouri     1271
# Kansas       1260
# Name: sat_composite_score_2017, dtype: int64

# %%
mean_sat_score_2017.sort_values(ascending=False).tail(5)
# Out:
# state
# Maine                   1012
# Michigan                1005
# Idaho                   1005
# Delaware                 996
# District of Columbia     950
# Name: sat_composite_score_2017, dtype: int64

# %%
mean_sat_score_2018= df_final.groupby("state")["sat_composite_score_2018"].mean()
mean_sat_score_2018.sort_values(ascending=False).head(5)
# Out:
# state
# Minnesota       1298
# Wisconsin       1294
# North Dakota    1283
# Iowa            1265
# Kansas          1265
# Name: sat_composite_score_2018, dtype: int64

# %%
mean_sat_score_2018.sort_values(ascending=False).tail(5)
# Out:
# state
# Michigan                1011
# Idaho                   1001
# West Virginia            999
# Delaware                 998
# District of Columbia     977
# Name: sat_composite_score_2018, dtype: int64

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT? Minnesota    1295, District of Columbia     950
#     - 2018 SAT?Minnesota       1298, District of Columbia     977
#     - 2017 ACT?New Hampshire           25.5, Nevada            17.8
#     - 2018 ACT?Connecticut      25.6 Nevada            17.8

# %%
act_change_over_year = (mean_act_score_2018 - mean_act_score_2017)
sat_change_over_year = (mean_sat_score_2018 - mean_sat_score_2017)

# %%
act_rate_change_100 = ((df_final["act_percent_participation_2018"] == 100) & ((df_final["act_composite_score_2018"]-df_final["act_composite_score_2017"]) > 0))
sat_rate_change_100 = ((df_final["sat_percent_participation_2018"] == 100) & ((df_final["sat_composite_score_2018"]-df_final["sat_composite_score_2017"]) > 0))

# %%
df_final[act_rate_change_100]
# Out:
#        state  act_percent_participation_2017  act_english_2017  act_math_2017  \
# 17  Kentucky                             100              19.6           19.4
# 44      Utah                             100              19.5           19.9
#
#     act_reading_2017  act_science_2107  act_composite_score_2017  \
# 17              20.5              20.1                      20.0
# 44              20.8              20.6                      20.3
#
#     sat_percent_participation_2017  sat_reading_writing_2017  sat_math_2017  \
# 17                               4                       631            616
# 44                               3                       624            614
#
#     sat_composite_score_2017  act_percent_participation_2018  \
# 17                      1247                             100
# 44                      1238                             100
#
#     act_composite_score_2018  sat_percent_participation_2018  \
# ...

# %%
df_final[sat_rate_change_100]
# Out:
#           state  act_percent_participation_2017  act_english_2017  \
# 6   Connecticut                              31              25.5
# 7      Delaware                              18              24.1
# 22     Michigan                              29              24.1
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 6            24.6              25.6              24.6
# 7            23.4              24.8              23.6
# 22           23.7              24.5              23.8
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 6                       25.2                             100
# 7                       24.1                             100
# 22                      24.1                             100
#
#     sat_reading_writing_2017  sat_math_2017  sat_composite_score_2017  \
# 6                        530            512                      1041
# 7                        503            492                       996
# ...

# %%
act_rate_change_50 = (((df_final["act_percent_participation_2018"] > 50) & (df_final["sat_percent_participation_2018"] > 50)) & ((df_final["act_composite_score_2018"]-df_final["act_composite_score_2017"]) > 0))
sat_rate_change_50 = (((df_final["act_percent_participation_2018"] > 50) & (df_final["sat_percent_participation_2018"] > 50)) & ((df_final["sat_composite_score_2018"]-df_final["sat_composite_score_2017"]) > 0))

# %%
df_final[act_rate_change_50]
# Out:
#      state  act_percent_participation_2017  act_english_2017  act_math_2017  \
# 9  Florida                              73              19.0           19.4
#
#    act_reading_2017  act_science_2107  act_composite_score_2017  \
# 9              21.0              19.4                      19.8
#
#    sat_percent_participation_2017  sat_reading_writing_2017  sat_math_2017  \
# 9                              83                       520            497
#
#    sat_composite_score_2017  act_percent_participation_2018  \
# 9                      1017                              66
#
#    act_composite_score_2018  sat_percent_participation_2018  \
# 9                      19.9                              97
#
#    sat_reading_writing_2018  sat_math_2018  sat_composite_score_2018
# 9                       522            493                      1014

# %%
df_final[sat_rate_change_50]
# Out:
#              state  act_percent_participation_2017  act_english_2017  \
# 10         Georgia                              55              21.0
# 11          Hawaii                              90              17.8
# 33  North Carolina                             100              17.8
# 40  South Carolina                             100              17.5
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 10           20.9              22.0              21.3
# 11           19.2              19.2              19.3
# 33           19.3              19.6              19.3
# 40           18.6              19.1              18.9
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 10                      21.4                              61
# 11                      19.0                              55
# 33                      19.1                              49
# 40                      18.7                              50
#
# ...

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?
#     - Two states with a 100% participation in the ACT had a positive change year after year, Kentucky and Utah
#     - Three States  witha 100% participation in the SAT had a positive change year after year, Conneticut, Delaware, Michigan
# - Do any states show have >50% participation on *both* tests either year?
#     - Only Florida, participated in 2018 over 50% on both test saw a positive improvement in ACT test scores y-o-y
#     - Georgia, Hawaii, North Carolina, Sourth Carolina - Hard a participation >50% saw a positive test score y-o-y

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_final.corr())
plt.title("Correlation of SAT/ACT Scores and Percent Participation for 2017 and 2018")
# Out:
# Text(0.5,1,'Correlation of SAT/ACT Scores and Percent Participation for 2017 and 2018')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)                         # Makes sure you have enough rows
    (figure, ax) = plt.subplots(nrows=nrows, ncols=2, figsize=(7,10))        # You'll want to specify your figsize
    ax = ax.ravel()                                     # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):        # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])                   # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Code
figure, ax = plt.subplots(nrows = 2, ncols = 1, figsize=(5,10));

# Identify each graph with a variable to add labels and titles below
act = df_final['act_percent_participation_2017'].plot(title="2017 ACT Participation %", 
                                           kind="hist", ax=ax[0], color="yellow", alpha=.5)
sat = df_final['sat_percent_participation_2017'].plot(title="2017 SAT Participation %", 
                                           kind="hist", ax=ax[1], color="blue", alpha=.5)

# Updating labels for each graph
act.set_xlabel('Participation %')
act.set_ylabel('Frequency')


sat.set_xlabel('Participation %')
sat.set_ylabel('Frequency')

# Setting titles for each graph
act.set_title('% of ACT Participation')
sat.set_title('% of SAT Participation');

# %%
figure, ax = plt.subplots(nrows = 2, ncols = 1, figsize=(5,10));

# Identify each graph with a variable to add labels and titles below
act = df_final['act_math_2017'].plot(title="2017 ACT Math Score", 
                                           kind="hist", ax=ax[0], color="Green", alpha=.5)
sat = df_final['sat_math_2017'].plot(title="2017 SAT Math Score", 
                                           kind="hist", ax=ax[1], color="Orange", alpha=.5)

# Updating labels for each graph
act.set_xlabel('Math Score')
act.set_ylabel('Frequency')


sat.set_xlabel('Math Score')
sat.set_ylabel('Frequency')

# Setting titles for each graph
act.set_title('2017 ACT Math Score')
sat.set_title('2017 SAT Math Score');

# %%
figure, ax = plt.subplots(nrows = 2, ncols = 1, figsize=(5,10));

# Identify each graph with a variable to add labels and titles below
act = df_final['act_english_2017'].plot(title="2017 ACT English", 
                                           kind="hist", ax=ax[0], color="Blue", alpha=.5)
sat = df_final['sat_reading_writing_2017'].plot(title="2017 SAT English", 
                                           kind="hist", ax=ax[1], color="Orange", alpha=.5)

# Updating labels for each graph
act.set_xlabel('English Score')
act.set_ylabel('Frequency')


sat.set_xlabel('English Score')
sat.set_ylabel('Frequency')

# Setting titles for each graph
act.set_title('ACT 2017 English Score')
sat.set_title('ACT 2017 English Score');

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Establish the size of the figure.
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["act_math_2017"], 
           df_final["sat_math_2017"])

plt.title("SAT vs ACT Math Score 2017")
plt.ylabel("SAT Score", fontsize = 20)
plt.xlabel("ACT Score", fontsize = 20);

# %%
# Establish the size of the figure.
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["act_english_2017"], 
           df_final["sat_reading_writing_2017"])

plt.title("SAT vs ACT English Score 2017")
plt.ylabel("SAT Score", fontsize = 20)
plt.xlabel("ACT Score", fontsize = 20);

# %%
# Code# Establish the size of the figure.
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["act_composite_score_2017"], 
           df_final["sat_composite_score_2017"])

plt.title("SAT vs ACT Composite Score 2017")
plt.ylabel("SAT Score", fontsize = 20)
plt.xlabel("ACT Score", fontsize = 20);

# %%
# Establish the size of the figure.
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["sat_composite_score_2017"], 
           df_final["sat_composite_score_2018"])

plt.title("SAT 2017 vs SAT 2018 Composite Score")
plt.ylabel("SAT 2018 Score", fontsize = 20)
plt.xlabel("SAT 2017 Score", fontsize = 20);

# %%
# Establish the size of the figure.
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["act_composite_score_2017"], 
           df_final["act_composite_score_2018"])

plt.title("ACT 2017 vs ACT 2018 Composite Score")
plt.ylabel("ACT 2018 Score", fontsize = 20)
plt.xlabel("ACT 2017 Score", fontsize = 20);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
sns.boxplot(df_final["act_composite_score_2017"], df_final["act_composite_score_2018"])
# Out:
# C:\Users\Trisarah\Anaconda3\envs\dsi\lib\site-packages\seaborn\categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
# All ACT scores
df = pd.DataFrame(data = np.random.random(size=(4,4)), columns = ['act_composite_score_2017','act_composite_score_2018','sat_composite_score_2017','sat_composite_score_2018'])

sns.boxplot(x="variable", y="value", data=pd.melt(df))
# Out:
# C:\Users\Trisarah\Anaconda3\envs\dsi\lib\site-packages\seaborn\categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
df_final.describe()
# Out:
#        act_percent_participation_2017  act_english_2017  act_math_2017  \
# count                       51.000000         51.000000      51.000000
# mean                        65.254902         20.931373      21.182353
# std                         32.140842          2.353677       1.981989
# min                          8.000000         16.300000      18.000000
# 25%                         31.000000         19.000000      19.400000
# 50%                         69.000000         20.700000      20.900000
# 75%                        100.000000         23.300000      23.100000
# max                        100.000000         25.500000      25.300000
#
#        act_reading_2017  act_science_2107  act_composite_score_2017  \
# count         51.000000         51.000000                 51.000000
# mean          22.013725         21.041176                 21.519608
# std            2.067271          3.182463                  2.020695
# ...

# %% [markdown]
# Answers:
#
# All Scores:
# - Participation in the ACT has decreased over time. The SAT precent participation has increased from 2017 to 2018, with the mean ACT decreasing over that same period of time. The scores have stayed relatively the same, with the mean change in score being less than a 5% over that same period.
#
# ACT Scores
# - The mean act score changed from 21.39 in 2018 from 20.51.  2.02 STD in 2017 but increased to 2.11 in 2018.
# - IN general scores have not gotten significantly better over time and no indication on all fronts that it will
#
# SAT Scores
# - The same thing can be seen with scores from 2017 and 2018 as participation increase the STD in scores have also increased, while the chnage in scores remain the same.  The interesting note is that the min scores has increased over time.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
#
# I think we would get a normal distribution if we get a sample of the entire population

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# Certain states mandate testing and some do not.  Taking the distribution acorss the entire nation will allow us to remove that biasis and make better inference between scores and how it has changed over time.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# No, participation rate is dependent on the state.  The volutary aspect of some states as well as percent college graduates will inflate the data. In addition the inference doesn't really tell us the information we are looking for. Which is the relationship that will increase SAT or ACT grades.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
# No, the numbers are completely different. If you want to compare the quality of the the math scores you have to have a common basis. The percent of perfect score would be a good measure between the SAT and ACT math scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
act_rate_change_1 = ((df_final["act_percent_participation_2017"] > 80) & (df_final["act_percent_participation_2018"] < 50))
sat_rate_change_1 = ((df_final["sat_percent_participation_2017"] < 50) & (df_final["sat_percent_participation_2018"] > 50))

# %%
df_final[act_rate_change_1]
# Out:
#        state  act_percent_participation_2017  act_english_2017  act_math_2017  \
# 5   Colorado                             100              20.1           20.3
# 13  Illinois                              93              21.0           21.2
#
#     act_reading_2017  act_science_2107  act_composite_score_2017  \
# 5               21.2              20.9                      20.8
# 13              21.6              21.3                      21.4
#
#     sat_percent_participation_2017  sat_reading_writing_2017  sat_math_2017  \
# 5                               11                       606            595
# 13                               9                       559            556
#
#     sat_composite_score_2017  act_percent_participation_2018  \
# 5                       1201                              30
# 13                      1115                              43
#
#     act_composite_score_2018  sat_percent_participation_2018  \
# ...

# %%
df_final[sat_rate_change_1]
# Out:
#              state  act_percent_participation_2017  act_english_2017  \
# 5         Colorado                             100              20.1
# 13        Illinois                              93              21.0
# 33  North Carolina                             100              17.8
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 5            20.3              21.2              20.9
# 13           21.2              21.6              21.3
# 33           19.3              19.6              19.3
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 5                       20.8                              11
# 13                      21.4                               9
# 33                      19.1                              49
#
#     sat_reading_writing_2017  sat_math_2017  sat_composite_score_2017  \
# 5                        606            595                      1201
# 13                       559            556                      1115
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
both_act_sat = ((df_final["act_percent_participation_2018"] > 80) & (df_final["sat_percent_participation_2018"] > 50))

# %%
df_final[both_act_sat]
# Out:
#              state  act_percent_participation_2017  act_english_2017  \
# 11          Hawaii                              90              17.8
# 33  North Carolina                             100              17.8
# 40  South Carolina                             100              17.5
#
#     act_math_2017  act_reading_2017  act_science_2107  \
# 11           19.2              19.2              19.3
# 33           19.3              19.6              19.3
# 40           18.6              19.1              18.9
#
#     act_composite_score_2017  sat_percent_participation_2017  \
# 11                      19.0                              55
# 33                      19.1                              49
# 40                      18.7                              50
#
#     sat_reading_writing_2017  sat_math_2017  sat_composite_score_2017  \
# 11                       544            541                      1085
# 33                       546            535                      1081
# ...

# %%
plt.figure(figsize=(20, 9))

# Create scatter plot SAT score vs Math score.
plt.scatter(df_final["sat_composite_score_2018"], 
           df_final["sat_percent_participation_2018"])

plt.title("SAT Score vs SAT Percent Participation 2018")
plt.ylabel("Percent Participation", fontsize = 20)
plt.xlabel("SAT Score", fontsize = 20);
